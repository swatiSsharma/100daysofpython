# %% [markdown]
# # Rounded Division
#
# **Problem Description**
#
# Given an integer A, find the rounded value of real number A / 200.
# Rounded value of a real number X is the integer which is nearest to X, with halfway cases rounded away from zero.
#
# Some examples:
#
# Rounded value of 2.4 = 2
# Rounded value of 2.5 = 3
# Rounded value of 2.6 = 3
# Rounded value of 0.0 = 0
# Rounded value of -2.4 = -2
# Rounded value of -2.5 = -3
# Rounded value of -2.6 = -3
#
# **Problem Constraints**
#
# -108 <= A <= 108
#
#
#
# **Input Format**
#
# First and only argument is an integer A.
#
# **Output Format**
#
# Return an integer denoting the rounded value of real number A / 200.
#
#
#
# **Example Input**
#
# Input 1: A = 2113
# <br>Input 2: A = -2113
# <br>Input 3: A = 7
# <br>Input 4: A = -400
#
#
# **Example Output**
# <br>Output 1: 11
# <br>Output 2: -11
# <br>Output 3: 0
# <br>Output 4: -2
#
# **Example Explanation**
#
# - Explanation 1:
#
#  A / 200 = 2113 / 200 = 10.565
#  Rounded value of 10.565 is 11.
#
# - Explanation 2:
#
#  A / 200 = -2113 / 200 = -10.565
#  Rounded value of -10.565 is -11.
#
# - Explanation 3:
#
#  A / 200 = 7 / 200 = 0.035
#  Rounded value of 0.035 is 0.
#
# - Explanation 4:
#
#  A / 200 = -400 / 200 = -2.00
#  Rounded value of -2.00 is -2.

# %%
class Solution:
    # @param A : integer
    # @return an integer
    def solve(self, A):
        import math
        val = A/200
        val1 = A//200 
        if val < 0 and val1 < val:
            num1 = (math.modf(val))
            if (num1[1] % 2 == 0 and num1[0] == 0.5) or (num1[1] % 2 == 0 and num1[0] == -0.5):
                a = round(val1)
            else:
                a = round(val) 
        elif val > 0:
            num = (math.modf(val))
            if num[1] % 2 == 0 and num[0] == 0.5:
                a = round(val) + 1
            else:
                a = round(val)
        else:
            a = round(val)
        
        return a
        
obj = Solution
